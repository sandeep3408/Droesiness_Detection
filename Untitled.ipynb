# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import cv2

# %%
image = cv2.imread('Dataset/train/open/s0001_01849_0_0_1_0_0_01.png', cv2.IMREAD_GRAYSCALE)
if image is not None:
    import matplotlib.pyplot as plt
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()
else:
    print("Error: Image could not be loaded.")

# %%
gray_image = cv2.imread('Dataset/train/open/s0001_01849_0_0_1_0_0_01.png', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(gray_image,cmap='gray')

# %%
gray_image.shape
# Out:
# (79, 79)

# %%
rgb_image = cv2.cvtColor(gray_image, cv2.COLOR_GRAY2RGB)

# %%
plt.imshow(rgb_image,cmap='gray')

# %%
rgb_image.shape
# Out:
# (79, 79, 3)

# %%
img_size = 224

# %%
resized_image = cv2.resize(rgb_image, (img_size, img_size))

# %%
resized_image.shape
# Out:
# (224, 224, 3)

# %%
training_data = []

def triaining():
    train = 'Dataset/train/'
    category = ['open','closed']
    for c in category:
        path = os.path.join(train,c)
        for img in os.listdir(path):
            img_path = os.path.join(path,img)
            gray_image = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
            rgb_image = cv2.cvtColor(gray_image, cv2.COLOR_GRAY2RGB)
            resized_image = cv2.resize(rgb_image, (img_size, img_size))
            training_data.append([resized_image,c])

# %%
triaining()

# %%
print(len(training_data))
# Out:
# 8171

# %%
training_data[0]
# Out:
# [array([[[35, 35, 35],
#          [35, 35, 35],
#          [36, 36, 36],
#          ...,
#          [94, 94, 94],
#          [94, 94, 94],
#          [94, 94, 94]],
#
#         [[35, 35, 35],
#          [35, 35, 35],
#          [36, 36, 36],
#          ...,
#          [93, 93, 93],
#          [94, 94, 94],
#          [94, 94, 94]],
#
#         [[35, 35, 35],
#          [35, 35, 35],
#          [37, 37, 37],
#          ...,
#          [94, 94, 94],
#          [94, 94, 94],
#          [94, 94, 94]],
#
#         ...,
#
#         [[54, 54, 54],
#          [54, 54, 54],
#          [54, 54, 54],
#          ...,
#          [74, 74, 74],
#          [75, 75, 75],
#          [75, 75, 75]],
#
#         [[55, 55, 55],
#          [55, 55, 55],
#          [55, 55, 55],
#          ...,
#          [74, 74, 74],
#          [75, 75, 75],
#          [75, 75, 75]],
#
#         [[55, 55, 55],
#          [55, 55, 55],
#          [55, 55, 55],
#          ...,
#          [74, 74, 74],
# ...

# %%
training_data[0][0].shape
# Out:
# (224, 224, 3)

# %%
X = []
y = []

for f,l in training_data:
    X.append(f)
    y.append(l)

# %%
X[0].shape
# Out:
# (224, 224, 3)

# %%
print(np.array(X))
# Out:
# [[[[ 35  35  35]
#    [ 35  35  35]
#    [ 36  36  36]
#    ...
#    [ 94  94  94]
#    [ 94  94  94]
#    [ 94  94  94]]
#
#   [[ 35  35  35]
#    [ 35  35  35]
#    [ 36  36  36]
#    ...
#    [ 93  93  93]
#    [ 94  94  94]
#    [ 94  94  94]]
#
#   [[ 35  35  35]
#    [ 35  35  35]
#    [ 37  37  37]
#    ...
#    [ 94  94  94]
#    [ 94  94  94]
#    [ 94  94  94]]
#
#   ...
#
#   [[ 54  54  54]
#    [ 54  54  54]
#    [ 54  54  54]
#    ...
#    [ 74  74  74]
#    [ 75  75  75]
#    [ 75  75  75]]
#
#   [[ 55  55  55]
#    [ 55  55  55]
#    [ 55  55  55]
#    ...
#    [ 74  74  74]
#    [ 75  75  75]
#    [ 75  75  75]]
#
#   [[ 55  55  55]
#    [ 55  55  55]
#    [ 55  55  55]
#    ...
#    [ 74  74  74]
#    [ 75  75  75]
#    [ 75  75  75]]]
#
#
#  [[[ 94  94  94]
#    [ 94  94  94]
#    [ 93  93  93]
#    ...
#    [ 50  50  50]
#    [ 51  51  51]
#    [ 51  51  51]]
#
#   [[ 94  94  94]
#    [ 94  94  94]
#    [ 93  93  93]
#    ...
#    [ 50  50  50]
#    [ 51  51  51]
# ...

# %%
X = np.array(X).reshape(-1,img_size,img_size,3)

# %%
X.shape
# Out:
# (8171, 224, 224, 3)

# %%
X[0].shape
# Out:
# (224, 224, 3)

# %%
test_data = []
img_size2 = (224,224)
def test():
    test = 'Dataset/test/'
    category = ['open','closed']
    for c in category:
        c1 = category.index(c)
        path = os.path.join(test,c)
        for img in os.listdir(path):
            img_path = os.path.join(path,img)
            gray_image = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
            rgb_image = cv2.cvtColor(gray_image, cv2.COLOR_GRAY2RGB)
            resized_image = cv2.resize(rgb_image, img_size2)
            test_data.append([resized_image,c1])

# %%
test()

# %%
print(len(test_data))
# Out:
# 2345

# %%
test_data[0][0].shape
# Out:
# (224, 224, 3)

# %%
import random

# %%
random.shuffle(test_data)

# %%
a = []
b = []

for f,l in test_data:
    a.append(f)
    b.append(l)

# %%
a[0]
# Out:
# array([[[ 63,  63,  63],
#         [ 63,  63,  63],
#         [ 63,  63,  63],
#         ...,
#         [122, 122, 122],
#         [120, 120, 120],
#         [120, 120, 120]],
#
#        [[ 63,  63,  63],
#         [ 63,  63,  63],
#         [ 63,  63,  63],
#         ...,
#         [122, 122, 122],
#         [120, 120, 120],
#         [120, 120, 120]],
#
#        [[ 62,  62,  62],
#         [ 62,  62,  62],
#         [ 62,  62,  62],
#         ...,
#         [121, 121, 121],
#         [120, 120, 120],
#         [119, 119, 119]],
#
#        ...,
#
#        [[ 73,  73,  73],
#         [ 73,  73,  73],
#         [ 74,  74,  74],
#         ...,
#         [ 91,  91,  91],
#         [ 91,  91,  91],
#         [ 91,  91,  91]],
#
#        [[ 73,  73,  73],
#         [ 73,  73,  73],
#         [ 74,  74,  74],
#         ...,
#         [ 92,  92,  92],
#         [ 92,  92,  92],
#         [ 93,  93,  93]],
#
#        [[ 73,  73,  73],
#         [ 73,  73,  73],
#         [ 74,  74,  74],
# ...

# %%
b[0]
# Out:
# 1

# %%
a = np.array(a).reshape(-1,224,224,3)

# %%
a[0].shape
# Out:
# (224, 224, 3)

# %%
a = a/255.0

# %%
a[0].shape
# Out:
# (224, 224, 3)

# %%
a[0]
# Out:
# array([[[0.24705882, 0.24705882, 0.24705882],
#         [0.24705882, 0.24705882, 0.24705882],
#         [0.24705882, 0.24705882, 0.24705882],
#         ...,
#         [0.47843137, 0.47843137, 0.47843137],
#         [0.47058824, 0.47058824, 0.47058824],
#         [0.47058824, 0.47058824, 0.47058824]],
#
#        [[0.24705882, 0.24705882, 0.24705882],
#         [0.24705882, 0.24705882, 0.24705882],
#         [0.24705882, 0.24705882, 0.24705882],
#         ...,
#         [0.47843137, 0.47843137, 0.47843137],
#         [0.47058824, 0.47058824, 0.47058824],
#         [0.47058824, 0.47058824, 0.47058824]],
#
#        [[0.24313725, 0.24313725, 0.24313725],
#         [0.24313725, 0.24313725, 0.24313725],
#         [0.24313725, 0.24313725, 0.24313725],
#         ...,
#         [0.4745098 , 0.4745098 , 0.4745098 ],
#         [0.47058824, 0.47058824, 0.47058824],
#         [0.46666667, 0.46666667, 0.46666667]],
#
#        ...,
#
#        [[0.28627451, 0.28627451, 0.28627451],
# ...

# %%
B = np.array(b)

# %%
b[0]
# Out:
# 1

# %%
B[0]
# Out:
# 1

# %%
B
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
import pickle

# %%
a.shape
# Out:
# (2345, 224, 224, 3)

# %%
type(b)
# Out:
# list

# %%
type(B)
# Out:
# numpy.ndarray

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
from tensorflow.keras import layers

# %%
model =tf.keras.applications.mobilenet.MobileNet()

# %%
model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)        576
#  )
#
# ...

# %%
base_input = model.layers[0].input

# %%
base_output = model.layers[-4].output

# %%
flat_layer = layers.Flatten()(base_output)
f_output = layers.Dense(1)(flat_layer)
f_output = layers.Activation('sigmoid')(f_output)

# %%
new_model = keras.Model(inputs = base_input, outputs = f_output)

# %%
new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)        576
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 56, 56, 64)        256
# ...

# %%
# batch_size = 32  

# new_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# new_model.fit(a, B, epochs=20, batch_size=batch_size, validation_split=0.1)

from keras.preprocessing.image import ImageDataGenerator

# Define data augmentation and preprocessing for images
data_generator = ImageDataGenerator(
    rescale=1.0/255.0,  # Rescale pixel values to [0, 1]
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.1  # Split data into training and validation sets
)

# Define batch size and image dimensions
batch_size = 32
img_height = 224
img_width = 224

# Create training data generator
train_generator = data_generator.flow_from_directory(
    'Dataset/train/',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'  # Specify 'training' subset for training data
)

# Create validation data generator
validation_generator = data_generator.flow_from_directory(
    'Dataset/test/',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'  # Specify 'validation' subset for validation data
)

# # Compile and train your model using the data generators
# new_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# history = new_model.fit(
#     train_generator,
#     epochs=20,
#     validation_data=validation_generator
# )
# Out:
# Found 7355 images belonging to 2 classes.
# Found 234 images belonging to 2 classes.

# %%
new_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = new_model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator
)
# Out:
# Epoch 1/10
# 230/230 [==============================] - 592s 3s/step - loss: 0.1122 - accuracy: 0.9657 - val_loss: 0.2173 - val_accuracy: 0.8376
# Epoch 2/10
# 230/230 [==============================] - 574s 2s/step - loss: 0.0489 - accuracy: 0.9825 - val_loss: 0.0110 - val_accuracy: 0.9957
# Epoch 3/10
# 230/230 [==============================] - 547s 2s/step - loss: 0.0458 - accuracy: 0.9844 - val_loss: 0.0559 - val_accuracy: 0.9915
# Epoch 4/10
# 230/230 [==============================] - 554s 2s/step - loss: 0.0393 - accuracy: 0.9865 - val_loss: 0.0944 - val_accuracy: 0.9615
# Epoch 5/10
# 230/230 [==============================] - 569s 2s/step - loss: 0.0351 - accuracy: 0.9868 - val_loss: 0.0935 - val_accuracy: 0.9744
# Epoch 6/10
# 230/230 [==============================] - 576s 3s/step - loss: 0.0376 - accuracy: 0.9859 - val_loss: 0.1095 - val_accuracy: 0.9530
# Epoch 7/10
# ...

# %%
new_model.save('my_model.h5')

# %%
imgg = cv2.imread('Dataset/train/open/s0001_01849_0_0_1_0_0_01.png',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imgg,cmap='gray')

# %%
backtorgb = cv2.cvtColor(imgg,cv2.COLOR_GRAY2RGB)

# %%
newimg = cv2.resize(backtorgb,(224,224))

# %%
X_input = np.array(newimg).reshape(1,224,224,3)

# %%
X_input.shape
# Out:
# (1, 224, 224, 3)

# %%
plt.imshow(newimg)

# %%
X_input = X_input/255.0

# %%
pred = new_model.predict(X_input)
# Out:
# 1/1 [==============================] - 0s 333ms/step

# %%
pred
# Out:
# array([[0.9996501]], dtype=float32)

# %%
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'Dataset/haarcascade_eye.xml')

# %%
frontal_face = cv2.CascadeClassifier(cv2.data.haarcascades+'Dataset/haarcascade_frontalface_default.xml')

# %%
imgg = cv2.imread('sllep.jpg',cv2.IMREAD_COLOR)
# gray = cv2.cvtColor(imgg,cv2.COLOR_BGR2GRAY)

# %%
gray = cv2.cvtColor(imgg,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray)

# %%
img = cv2.imread('sllep.jpg')

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
haar_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'Dataset/haarcascade_frontalface_default.xml')

# %%
import cv2

# Load the Haar cascade classifier
haar_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eyecas = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Check if the cascade classifier is loaded successfully
if eyecas.empty():
    print("Error loading cascade classifier.")
else:
    print("Cascade classifier loaded successfully.")
# Out:
# Cascade classifier loaded successfully.

# %%
imaag = cv2.imread('man.jpg')
gra = cv2.cvtColor(imaag, cv2.COLOR_BGR2GRAY)

# %%
faces_rect = haar_cascade.detectMultiScale(gra, scaleFactor=1.1, minNeighbors=5)

# %%
for (x, y, w, h) in faces_rect:
    cv2.rectangle(imaag, (x, y), (x+w, y+h), (0, 255, 0), 2)

# Display the image with detected faces
cv2.imshow('Detected Faces', imaag)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load the input image
imgh = cv2.imread('eye.jpg')

# Convert the image to grayscale
gray_imggg = cv2.cvtColor(imgh, cv2.COLOR_BGR2GRAY)

# Load the Haar cascade classifier for eye detection
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Detect eyes in the image
eyes_rect = eye_cascade.detectMultiScale(gray_imggg, scaleFactor=1.1, minNeighbors=5)

# Draw rectangles around the detected eyes
for (x, y, w, h) in eyes_rect:
    cv2.rectangle(imgh, (x, y), (x+w, y+h), (0, 255, 0), 2)

# Display the image with detected eyes
cv2.imshow('Detected Eyes', imgh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
if len(eyes_rect) > 0:
    # Crop the first detected eye (you can modify this to crop the desired eye)
    (x, y, w, h) = eyes_rect[0]  # Selecting the first detected eye
    cropped_eye = imgh[y:y+h, x:x+w]

    # Display the cropped eye
    cv2.imshow('Cropped Eye', cropped_eye)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("No eyes detected in the image.")

# %%
cropped_eye.shape
# Out:
# (38, 38, 3)

# %%
final = cv2.resize(cropped_eye,(224,224))
final = np.expand_dims(final,axis=0)
final = final/255.0

# %%
final.shape
# Out:
# (1, 224, 224, 3)

# %%
new_model.predict(final)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[0.00055765]], dtype=float32)

# %%
plt.imshow(cv2.cvtColor(cropped_eye,cv2.COLOR_BGR2RGB))

# %%
import cv2

# Load the pre-trained Haar cascade classifiers
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Initialize the video capture object for webcam
cap = cv2.VideoCapture(0)  # Use 0 for the default webcam

while cap.isOpened():
    # Read a frame from the webcam
    ret, frame = cap.read()
    if not ret:
        break

    # Convert the frame to grayscale for better processing
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5)

    # Iterate over detected faces
    for (x, y, w, h) in faces:
        # Draw rectangle around the face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        # Extract the region of interest (ROI) for eyes
        roi_gray = gray_frame[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]

        # Detect eyes in the face ROI
        eyes = eye_cascade.detectMultiScale(roi_gray)

        # Check if eyes are open or closed
#         if len(eyes) == 0:
#             eye_status = "Closed"
#         else:
#             eye_status = "Open"

        # Display eye status text for each face
        cv2.putText(frame, f'Eye Status: {eye_status}', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        # Iterate over detected eyes and draw rectangles
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)
        
        
        f_img = cv2.resize(roi_color,(224,224))
        f_img = np.expand_dims(f_img,axis=0)
        f_img = f_img/255.0
            
        model_output = new_model.predict(f_img)

            # Determine eye status based on model output and threshold
        if model_output > 0.3:
            eye_status = "Open"
        else:
            eye_status = "Closed"

    # Display the processed frame with detections
    cv2.imshow('Video', frame)

    # Check for user interrupt (press 'esc' to exit)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
i
