# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import cv2

# %%
gray_image = cv2.imread('Dataset/train/open/s0001_01849_0_0_1_0_0_01.png', cv2.IMREAD_GRAYSCALE)

# %%
image = cv2.imread('Dataset/train/open/s0001_01849_0_0_1_0_0_01.png', cv2.IMREAD_GRAYSCALE)
if image is not None:
    import matplotlib.pyplot as plt
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()
else:
    print("Error: Image could not be loaded.")

# %%
plt.imshow(gray_image,cmap='gray')

# %%
gray_image.shape
# Out:
# (79, 79)

# %%
# train = 'Dataset/train/'
# category = ['open','closed']
# for c in category:
#     path = os.path.join(train,c)
#     for img in os.listdir(path):
#         gray_image_path = os.path.join(path,img)
#         gray_image = cv2.imread(gray_image_path,cv2.IMREAD_GRAYSCALE)
#         plt.imshow(gray_image,cmap='gray')
#         break

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 gray_img2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
